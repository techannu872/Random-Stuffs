# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Transformation_Housing_Data=pd.read_csv('/content/drive/MyDrive/Classrooms internshala/internshala material/M4T3V0_helper_text/2.0 transformed dta/Transformed_Housing_Data.csv')

# %%
Transformation_Housing_Data.head()
# Out:
#            ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront View  \
# 0               1180.0              5650.0           1.0              No
# 1               2570.0              7242.0           2.0              No
# 2                770.0             10000.0           1.0              No
# 3               1960.0              5000.0           1.0              No
# 4               1680.0              8080.0           1.0              No
#
#    No of Times Visited Condition of the House  ...  \
# 0                    0                   Fair  ...
# 1                    0                   Fair  ...
# ...

# %%
Transformation_Housing_Data['Sale Price'].corr(Transformation_Housing_Data['Flat Area (in Sqft)'])
# Out:
# 0.6951704258420669

# %%
np.corrcoef(Transformation_Housing_Data['Sale Price'], Transformation_Housing_Data['Flat Area (in Sqft)'])
# Out:
# array([[1.        , 0.69517043],
#        [0.69517043, 1.        ]])

# %%
#sbowing other independent variables correlation
Transformation_Housing_Data.drop(columns=['ID']).corr()
# Out:
# <ipython-input-18-4c05a6daa683>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Transformation_Housing_Data.drop(columns=['ID']).corr()
#                                            Sale Price  No of Bedrooms  \
# Sale Price                                   1.000000        0.339407
# No of Bedrooms                               0.339407        1.000000
# No of Bathrooms                              0.535124        0.515813
# Flat Area (in Sqft)                          0.695170        0.576628
# Lot Area (in Sqft)                           0.101319        0.031692
# No of Floors                                 0.298913        0.175536
# No of Times Visited                          0.356114        0.079575
# Overall Grade                                0.680914        0.349223
# ...
