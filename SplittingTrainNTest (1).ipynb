# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Transformed_Housing_Data_2=pd.read_csv('/content/drive/MyDrive/Classrooms internshala/internshala material/Transformed_Housing_Data2.csv')
Transformed_Housing_Data_2.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# 0              5650.0           1.0                    0              7
# 1              7242.0           2.0                    0              7
# 2             10000.0           1.0                    0              6
# 3              5000.0           1.0                    0              7
# 4              8080.0           1.0                    0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# ...

# %%
#Defining the dependent Y and Independent X variable usinf iloc()
Y=Transformed_Housing_Data_2.iloc[:,0]
X=Transformed_Housing_Data_2.iloc[:,1:31]
X.head()
# Out:
#    No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  \
# 0               3             1.00               1180.0              5650.0
# 1               3             2.25               2570.0              7242.0
# 2               2             1.00                770.0             10000.0
# 3               4             3.00               1960.0              5000.0
# 4               3             2.00               1680.0              8080.0
#
#    No of Floors  No of Times Visited  Overall Grade  \
# 0           1.0                    0              7
# 1           2.0                    0              7
# 2           1.0                    0              6
# 3           1.0                    0              7
# 4           1.0                    0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                     1180.0                        0
# ...

# %%
#to seperate using sklearn.model_selection library into train and test data
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test=train_test_split(X,Y,test_size=0.3)

#using shape( ) to know the dimensions
X_train.shape
# Out:
# (15126, 30)

# %%
X_test.shape
# Out:
# (6483, 30)

# %%
Y_train.shape
# Out:
# (15126,)

# %%
Y_test.shape
# Out:
# (6483,)
